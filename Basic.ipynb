# %% [markdown]
# # Baisc Syntax and symantics

# %%
# Case sensitive

name = "prajyot"
Name = "mulik"

print(name)
print(Name)
# Out:
# prajyot
# mulik

# %% [markdown]
# # Indentation
#
# ### Indentation is used to define structure and heirarchy of a code. unlike many other programmig languages use brackets {} to delimit block of a code, python uses indentation to determine grouping of a statement

# %%
age = 11
if age > 10:
    print("You are above 10 years")
# Out:
# You are above 10 years

# %%
# line continuation using backslash
total = 1 + 2 + 3 + \
        4 + 5 + 6
print(total)


# multi statement in single line using semicolon
a = 2 ; b = 5 ; c = a + b
print(c)
# Out:
# 21
# 7

# %%
age = 20
print(type(int(age)))
# Out:
# <class 'int'>

# %%
height = 5.9
type(height)
# Out:
# float

# %%
print(type(int(height)))
# Out:
# <class 'int'>

# %%
print(type(float(int(height))))
# Out:
# <class 'float'>

# %%
## Dynamic Typing
## python allows the type of variable to change as per program execution

var = 5
print(var, type(var))

var = "Hello"
print(var , type(var))

var = 5.5
print(var, type(var))
# Out:
# 5 <class 'int'>
# Hello <class 'str'>
# 5.5 <class 'float'>

# %%
#input

age = int(input("Enter your age: "))
print("Your age is:", age, type(age))
# Out:
# Your age is: 4 <class 'int'>

# %% [markdown]
# ## DataTypes
# #### 1. Definition:
#
# - Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
# - They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.
#
# #### 2. Importance of Data Types in Programming
# Explanation:
#
# - Data types ensure that data is stored in an efficient way.
# - They help in performing correct operations on data.
# - Proper use of data types can prevent errors and bugs in the program.

# %% [markdown]
# Video Outline:
# 1. Introduction to Data Types
# 2. Importance of Data Types in Programming
# 3. Basic Data Types
#    - Integers
#    - Floating-point numbers
#    - Strings
#    - Booleans
# 4. Advanced Data Types
#    - Lists
#    - Tuples
#    - Sets
#    - Dictionaries
# 5. Type Conversion
# 6. Practical Examples

# %%
## Integer Examples

age = 35 
type(age)
# Out:
# int

# %%
# float

height = 5.9
type(height)
# Out:
# float

# %%
# string

name = "Prajyot"
print(name, type(name))
# Out:
# Prajyot <class 'str'>

# %%
# boolean datatypes

is_student = True
print(is_student, type(is_student))
# Out:
# True <class 'bool'>

# %%
## common errors

result = "hello "+ 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 ## common errors
# ----> 3 result = "hello "+ 7
#
# TypeError: can only concatenate str (not "int") to str

# %%
## common errors

result = "hello "+ str(7)

print(result, type(result))
# Out:
# hello 7 <class 'str'>

# %% [markdown]
# # Operaters

# %% [markdown]
# ### Video Outline:
# 1. Introduction to Operators
# 2. Arithmetic Operators
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#    - Floor Division
#    - Modulus
#    - Exponentiation
# 3. Comparison Operators
#    - Equal to
#    - Not equal to
#    - Greater than
#    - Less than
#    - Greater than or equal to
#    - Less than or equal to
# 4. Logical Operators
#    - AND
#    - OR
#    - NOT
# 5. Practical Examples and Common Errors

# %%
# arithmetic operations

a = 10
b = 3       

result = a + b   # addition
print("Addition:", result)
subtraction = a - b  # subtraction
print("Subtraction:", subtraction)
multiplication = a * b  # multiplication
print("Multiplication:", multiplication)
division = a / b  # division
print("Division:", division)
floor_division = a // b  # floor division
print("Floor Division:", floor_division)
modulus = a % b  # modulus
print("Modulus:", modulus)      
exponentiation = a ** b  # exponentiation
print("Exponentiation:", exponentiation)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000

# %% [markdown]
# ## comparison operators

# %%
## comparison operators
## == Equal to 

a = 10
b = 10

a==b
# Out:
# True

# %%
str1= "prajyot"
str2 = "prajyot"
str1 == str2
# Out:
# True

# %%
# greater than > , less than < 

num1 = 15
num2 = 30

num1 > num2

num1 < num2
# Out:
# True

# %% [markdown]
# ## comparison operators

# %%
## And, Not OR

x= True
Y= True

result = x and Y
print(result)
# Out:
# True

# %%
## OR

x= False
Y= True

result = x and Y
print(result)
# Out:
# False
